# %%
#1 WRITE A PROGRAM TO PRINT THE 4TH ELEMENT FROM 1ST AND 4TH ELEMENT FROM LAST IN A TUPLE
numbers=(10,20,30,40,50,60,70,80,90)
print("Tuple:",numbers)
print("4th element from first:",numbers[3])
print("4th element from last:",numbers[-4])
# Out:
# Tuple: (10, 20, 30, 40, 50, 60, 70, 80, 90)
# 4th element from first: 40
# 4th element from last: 60

# %%
#2 WRITE A PROGRAM TO CHECK WHETHER AN ELEMENT EXISTS IN A TUPLE OR NOT
numbers=(10,20,30,40,50)
element =int(input("Enter element to search:"))
if element in numbers:
    print("Element exists in tuple")
else:
    print("Element does not exist in tuple")
# Out:
# Enter element to search: 60
# Element does not exist in tuple

# %%
#3 WRITE A PROGRAM TO CONVERT A LIST INTO TUPLE
numbers_list=[10,20,30,40,50]
numbers_tuple=tuple(numbers_list)
print("List:",numbers_list)
print("Tuple:",numbers_tuple)
# Out:
# List: [10, 20, 30, 40, 50]
# Tuple: (10, 20, 30, 40, 50)

# %%
#4 WRITE A PROGRAM TO FIND THE INDEX OF A ELEMENT IN TUPLE
numbers=(10,20,30,40,50)
element=int(input("Enter element:"))
if element in numbers:
    print("Index of element:",numbers.index(element))
else:
    print("Element not fount")
# Out:
# Enter element: 30
# Index of element: 2

# %%
#5 WRITE A PROGRAM TO REPLACE LAST VALUE OF TUPLES IN A LIST TO 100
numbers=[(10,20,30),(40,50,60,),(70,80,90)]
new_list=[]
for tup in numbers:
    new_tup=tup[:-1]+(100,)
    new_list.append(new_tup)
print("Original list:",numbers)
print("Updated list:",new_list)
# Out:
# Original list: [(10, 20, 30), (40, 50, 60), (70, 80, 90)]
# Updated list: [(10, 20, 100), (40, 50, 100), (70, 80, 100)]

# %%
#6 PYTHON ELEMENT TO FIND MAXIMUM AND MINIMUM ELEMENT IN TUPLE
numbers=(1,20,3,40,5,60)
maximum=max(numbers)
minimum=min(numbers)
print("Tuple:",numbers)
print("Maximum element:",maximum)
print("Minimum element:",minimum)
# Out:
# Tuple: (1, 20, 3, 40, 5, 60)
# Maximum element: 60
# Minimum element: 1

# %%
#PYTHON PROGRAM TO SWAP LAST AND FIRST ELEMENT OF A TUPLE
numbers=(10,20,30,40,50)
new_tuple=(numbers[-1],)+numbers[1:-1]+(numbers[0],)
print("Originl:",numbers)
print("Tuple after swapping:",new_tuple)
# Out:
# Originl: (10, 20, 30, 40, 50)
# Tuple after swapping: (50, 20, 30, 40, 10)
